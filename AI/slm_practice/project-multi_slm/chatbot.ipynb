# %%
# !pip install gradio==4.29.0
# !pip install openai==0.28
# !pip install accelerate==0.30.1
# !pip install transformers==4.39.3
# !pip install bitsandbytes==0.43.1
# !pip install peft==0.10.0
# Out:
# Collecting gradio==4.29.0
#   Downloading gradio-4.29.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (5.5.0)
# Requirement already satisfied: fastapi in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (0.115.6)
# Requirement already satisfied: ffmpy in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (0.5.0)
# Collecting gradio-client==0.16.1 (from gradio==4.29.0)
#   Downloading gradio_client-0.16.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (0.27.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (6.4.5)
# Requirement already satisfied: jinja2<4.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (3.1.5)
# Requirement already satisfied: markupsafe~=2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (3.10.0)
# Requirement already satisfied: numpy~=1.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (3.10.12)
# Requirement already satisfied: packaging in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (2.2.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (2.10.4)
# Requirement already satisfied: pydub in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (0.9.1)
# Requirement already satisfied: semantic-version~=2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (2.10.0)
# Collecting tomlkit==0.12.0 (from gradio==4.29.0)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (2.3.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio==4.29.0) (0.25.0)
# Requirement already satisfied: fsspec in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from gradio-client==0.16.1->gradio==4.29.0) (2024.9.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.16.1->gradio==4.29.0)
#   Downloading websockets-11.0.3-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: jsonschema>=3.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from altair<6.0,>=4.2.0->gradio==4.29.0) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from altair<6.0,>=4.2.0->gradio==4.29.0) (1.22.0)
# Requirement already satisfied: anyio in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.24.1->gradio==4.29.0) (4.7.0)
# Requirement already satisfied: certifi in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.24.1->gradio==4.29.0) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.24.1->gradio==4.29.0) (1.0.7)
# Requirement already satisfied: idna in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.24.1->gradio==4.29.0) (3.10)
# Requirement already satisfied: sniffio in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpx>=0.24.1->gradio==4.29.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.29.0) (0.14.0)
# Requirement already satisfied: filelock in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->gradio==4.29.0) (3.16.1)
# Requirement already satisfied: requests in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->gradio==4.29.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->gradio==4.29.0) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==4.29.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==4.29.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==4.29.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==4.29.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==4.29.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==4.29.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio==4.29.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio==4.29.0) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pydantic>=2.0->gradio==4.29.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pydantic>=2.0->gradio==4.29.0) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio==4.29.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio==4.29.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio==4.29.0) (13.9.4)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from fastapi->gradio==4.29.0) (0.41.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.29.0) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.29.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.29.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.29.0) (0.22.3)
# Requirement already satisfied: six>=1.5 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.29.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.29.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.29.0) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.3->gradio==4.29.0) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==4.29.0) (0.1.2)
# Downloading gradio-4.29.0-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading gradio_client-0.16.1-py3-none-any.whl (314 kB)
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading websockets-11.0.3-py3-none-any.whl (118 kB)
# Installing collected packages: websockets, tomlkit, gradio-client, gradio
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.1
#     Uninstalling websockets-14.1:
#       Successfully uninstalled websockets-14.1
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.13.2
#     Uninstalling tomlkit-0.13.2:
#       Successfully uninstalled tomlkit-0.13.2
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.5.4
#     Uninstalling gradio_client-1.5.4:
#       Successfully uninstalled gradio_client-1.5.4
#   Attempting uninstall: gradio
#     Found existing installation: gradio 5.12.0
#     Uninstalling gradio-5.12.0:
#       Successfully uninstalled gradio-5.12.0
# Successfully installed gradio-4.29.0 gradio-client-0.16.1 tomlkit-0.12.0 websockets-11.0.3
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: openai==0.28 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from openai==0.28) (2.32.3)
# Requirement already satisfied: tqdm in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from openai==0.28) (4.67.1)
# Requirement already satisfied: aiohttp in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from openai==0.28) (3.11.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests>=2.20->openai==0.28) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests>=2.20->openai==0.28) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests>=2.20->openai==0.28) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests>=2.20->openai==0.28) (2024.12.14)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from aiohttp->openai==0.28) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from aiohttp->openai==0.28) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from aiohttp->openai==0.28) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from aiohttp->openai==0.28) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from aiohttp->openai==0.28) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from aiohttp->openai==0.28) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from aiohttp->openai==0.28) (1.18.3)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting accelerate==0.30.1
#   Downloading accelerate-0.30.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from accelerate==0.30.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from accelerate==0.30.1) (23.2)
# Requirement already satisfied: psutil in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from accelerate==0.30.1) (6.1.1)
# Requirement already satisfied: pyyaml in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from accelerate==0.30.1) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from accelerate==0.30.1) (2.5.1)
# Requirement already satisfied: huggingface-hub in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from accelerate==0.30.1) (0.27.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from accelerate==0.30.1) (0.4.5)
# Requirement already satisfied: filelock in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.10.0->accelerate==0.30.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.10.0->accelerate==0.30.1) (4.12.2)
# Requirement already satisfied: networkx in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.10.0->accelerate==0.30.1) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.10.0->accelerate==0.30.1) (3.1.5)
# Requirement already satisfied: fsspec in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.10.0->accelerate==0.30.1) (2024.9.0)
# Requirement already satisfied: setuptools in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.10.0->accelerate==0.30.1) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.10.0->accelerate==0.30.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate==0.30.1) (1.3.0)
# Requirement already satisfied: requests in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub->accelerate==0.30.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub->accelerate==0.30.1) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jinja2->torch>=1.10.0->accelerate==0.30.1) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->huggingface-hub->accelerate==0.30.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->huggingface-hub->accelerate==0.30.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->huggingface-hub->accelerate==0.30.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->huggingface-hub->accelerate==0.30.1) (2024.12.14)
# Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.2.1
#     Uninstalling accelerate-1.2.1:
#       Successfully uninstalled accelerate-1.2.1
# Successfully installed accelerate-0.30.1
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting transformers==4.39.3
#   Downloading transformers-4.39.3-py3-none-any.whl.metadata (134 kB)
# Requirement already satisfied: filelock in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers==4.39.3) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers==4.39.3) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers==4.39.3) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers==4.39.3) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers==4.39.3) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers==4.39.3) (2024.11.6)
# Requirement already satisfied: requests in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers==4.39.3) (2.32.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.39.3)
#   Downloading tokenizers-0.15.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers==4.39.3) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers==4.39.3) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->transformers==4.39.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->transformers==4.39.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->transformers==4.39.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->transformers==4.39.3) (2024.12.14)
# Downloading transformers-4.39.3-py3-none-any.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 4.6 MB/s eta 0:00:00a 0:00:01
# Downloading tokenizers-0.15.2-cp312-cp312-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.0
#     Uninstalling transformers-4.48.0:
#       Successfully uninstalled transformers-4.48.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.3.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.39.3 which is incompatible.
# Successfully installed tokenizers-0.15.2 transformers-4.39.3
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement bitsandbytes==0.43.1 (from versions: 0.31.8, 0.32.0, 0.32.1, 0.32.2, 0.32.3, 0.33.0, 0.33.1, 0.34.0, 0.35.0, 0.35.1, 0.35.2, 0.35.3, 0.35.4, 0.36.0, 0.36.0.post1, 0.36.0.post2, 0.37.0, 0.37.1, 0.37.2, 0.38.0, 0.38.0.post1, 0.38.0.post2, 0.38.1, 0.39.0, 0.39.1, 0.40.0, 0.40.0.post1, 0.40.0.post2, 0.40.0.post3, 0.40.0.post4, 0.40.1, 0.40.1.post1, 0.40.2, 0.41.0, 0.41.1, 0.41.2, 0.41.2.post1, 0.41.2.post2, 0.41.3, 0.41.3.post1, 0.41.3.post2, 0.42.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for bitsandbytes==0.43.1
# Collecting peft==0.10.0
#   Downloading peft-0.10.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (23.2)
# Requirement already satisfied: psutil in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (6.1.1)
# Requirement already satisfied: pyyaml in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (2.5.1)
# Requirement already satisfied: transformers in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (4.39.3)
# Requirement already satisfied: tqdm in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (0.30.1)
# Requirement already satisfied: safetensors in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from peft==0.10.0) (0.27.0)
# Requirement already satisfied: filelock in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (2024.9.0)
# Requirement already satisfied: requests in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (4.12.2)
# Requirement already satisfied: networkx in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.10.0) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.10.0) (3.1.5)
# Requirement already satisfied: setuptools in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.10.0) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.10.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.10.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers->peft==0.10.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from transformers->peft==0.10.0) (0.15.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from jinja2->torch>=1.13.0->peft==0.10.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.10.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.10.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.10.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wonik/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.10.0) (2024.12.14)
# Downloading peft-0.10.0-py3-none-any.whl (199 kB)
# Installing collected packages: peft
# Successfully installed peft-0.10.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !python3 chatbot.py
# Out:
# IMPORTANT: You are using gradio version 4.29.0, however version 4.44.1 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 4.29.0, however version 4.44.1 is available, please upgrade.
# --------
